# %%
import gym
import custom_robotics
import wrappers
from custom_policies import custom_feature_extractor

from stable_baselines3 import SAC#, HerReplayBuffer
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.vec_env import DummyVecEnv, VecVideoRecorder
import wandb
from wandb.integration.sb3 import WandbCallback

# %%
config = {
    "policy_type": "MultiInputPolicy",
    "total_timesteps": int(2e6),
    "env_name": "CustomFetchReach-v0",
    "name": "SAC_frame_stack_3dConv",
    "learning_starts": 10000,
    "buffer_size": 100000,
    "gamma": 0.95,
    "learning_rate": 0.001,
    "normalize": True
}

# %%
def make_env():
    env = gym.make(config["env_name"])
    env = Monitor(env)  # record stats such as returns
    env = wrappers.ImageAndRobot(env, 80, 80)
    env = wrappers.FrameStack(env, stack_size=4)
    return env
env = DummyVecEnv([make_env])

# %%
model = SAC(config["policy_type"], env, 
    learning_starts=1000, 
    buffer_size=config["buffer_size"],
    gamma=config["gamma"],
    learning_rate=config["learning_rate"],
    policy_kwargs=dict(
        features_extractor_class=custom_feature_extractor.CustomFeatureExtractor,
        features_extractor_kwargs=dict(custom_cnn=False),
        net_arch=[512, 512]
    ),
    verbose=1)
model.learn(
    total_timesteps=config["total_timesteps"],
)
# Out:
# Using cuda device
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -50      |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 537      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 200      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48.2    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 579      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 400      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -47.2    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 596      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 600      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -47.9    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 603      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 800      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48      |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 609      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 1000     |
# ---------------------------------
# Found 3 GPUs for rendering. Using device 0.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2157527/3863409413.py in <module>
#      10     ),
#      11     verbose=1)
# ---> 12 model.learn(
#      13     total_timesteps=config["total_timesteps"],
#      14 )
#
# ~/master/models/venv/lib/python3.8/site-packages/stable_baselines3/sac/sac.py in learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     289     ) -> OffPolicyAlgorithm:
#     290
# --> 291         return super(SAC, self).learn(
#     292             total_timesteps=total_timesteps,
#     293             callback=callback,
#
# ~/master/models/venv/lib/python3.8/site-packages/stable_baselines3/common/off_policy_algorithm.py in learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     369                 # Special case when the user passes `gradient_steps=0`
#     370                 if gradient_steps > 0:
# --> 371                     self.train(batch_size=self.batch_size, gradient_steps=gradient_steps)
#     372
#     373         callback.on_training_end()
#
# ~/master/models/venv/lib/python3.8/site-packages/stable_baselines3/sac/sac.py in train(self, gradient_steps, batch_size)
#     256             min_qf_pi, _ = th.min(q_values_pi, dim=1, keepdim=True)
#     257             actor_loss = (ent_coef * log_prob - min_qf_pi).mean()
# --> 258             actor_losses.append(actor_loss.item())
#     259
#     260             # Optimize the actor
#
# KeyboardInterrupt:

# %%
name = config["name"]
run = wandb.init(
    project="fetch-reach",
    entity="f-krone",
    name=name,
    config=config,
    sync_tensorboard=True,  # auto-upload sb3's tensorboard metrics
    monitor_gym=True,  # auto-upload the videos of agents playing the game
    save_code=True,  # optional
)


env = VecVideoRecorder(env, f"videos/fetch-reach/{name}_{run.id}", record_video_trigger=lambda x: x % 2000 == 0, video_length=200)
# Out:
# wandb: Currently logged in as: f-krone (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.12.10 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                     Syncing run <strong><a href="https://wandb.ai/f-krone/fetch-reach/runs/p8pqnpfl" target="_blank">SAC_frame_stack_3dConv</a></strong> to <a href="https://wandb.ai/f-krone/fetch-reach" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>

# %%
model = SAC(config["policy_type"], env, 
    learning_starts=config["learning_starts"], 
    buffer_size=config["buffer_size"],
    gamma=config["gamma"],
    learning_rate=config["learning_rate"],
    policy_kwargs=dict(
        features_extractor_class=custom_feature_extractor.CustomFeatureExtractor,
        features_extractor_kwargs=dict(custom_cnn=False),
        net_arch=[512, 512]
    ),
    verbose=1, tensorboard_log=f"runs/fetch-reach/{name}_{run.id}")
model.learn(
    total_timesteps=config["total_timesteps"],
    callback=WandbCallback(
        gradient_save_freq=100,
        model_save_path=f"models/fetch-reach/{name}_{run.id}",
        verbose=2,
    ),
)
model.save(f"{name}_fetch-reach")
# Out:
# Using cuda device
# Logging to runs/fetch-reach/SAC_frame_stack_3dConv_p8pqnpfl/SAC_1
# Saving video to /home/ws/upecj/master/models/src/videos/fetch-reach/SAC_frame_stack_3dConv_p8pqnpfl/rl-video-step-0-to-step-200.mp4
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49      |
# |    success_rate    | 0.25     |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 102      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 200      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49.5    |
# |    success_rate    | 0.125    |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 173      |
# |    time_elapsed    | 2        |
# |    total_timesteps | 400      |
# ---------------------------------
# ------------------------------------
# | rollout/           |             |
# |    ep_len_mean     | 50          |
# |    ep_rew_mean     | -49.7       |
# |    success_rate    | 0.083333336 |
# | time/              |             |
# |    episodes        | 12          |
# |    fps             | 226         |
# |    time_elapsed    | 2           |
# |    total_timesteps | 600         |
# ------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49.6    |
# |    success_rate    | 0.0625   |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 266      |
# |    time_elapsed    | 3        |
# |    total_timesteps | 800      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49.6    |
# |    success_rate    | 0.05     |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 299      |
# |    time_elapsed    | 3        |
# |    total_timesteps | 1000     |
# ---------------------------------
# ------------------------------------
# | rollout/           |             |
# |    ep_len_mean     | 50          |
# |    ep_rew_mean     | -49.7       |
# |    success_rate    | 0.041666668 |
# | time/              |             |
# |    episodes        | 24          |
# |    fps             | 326         |
# |    time_elapsed    | 3           |
# |    total_timesteps | 1200        |
# ------------------------------------
# ------------------------------------
# | rollout/           |             |
# |    ep_len_mean     | 50          |
# |    ep_rew_mean     | -49.7       |
# |    success_rate    | 0.035714287 |
# | time/              |             |
# |    episodes        | 28          |
# |    fps             | 349         |
# |    time_elapsed    | 4           |
# |    total_timesteps | 1400        |
# ------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49.8    |
# |    success_rate    | 0.03125  |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 367      |
# |    time_elapsed    | 4        |
# |    total_timesteps | 1600     |
# ---------------------------------
# ------------------------------------
# | rollout/           |             |
# |    ep_len_mean     | 50          |
# |    ep_rew_mean     | -49.8       |
# |    success_rate    | 0.027777778 |
# | time/              |             |
# |    episodes        | 36          |
# |    fps             | 384         |
# |    time_elapsed    | 4           |
# |    total_timesteps | 1800        |
# ------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49.8    |
# |    success_rate    | 0.025    |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 385      |
# |    time_elapsed    | 5        |
# |    total_timesteps | 2000     |
# ---------------------------------
# Saving video to /home/ws/upecj/master/models/src/videos/fetch-reach/SAC_frame_stack_3dConv_p8pqnpfl/rl-video-step-2000-to-step-2200.mp4
# ------------------------------------
# | rollout/           |             |
# |    ep_len_mean     | 50          |
# |    ep_rew_mean     | -49.8       |
# |    success_rate    | 0.022727273 |
# | time/              |             |
# |    episodes        | 44          |
# |    fps             | 319         |
# |    time_elapsed    | 6           |
# |    total_timesteps | 2200        |
# ------------------------------------
# ------------------------------------
# | rollout/           |             |
# |    ep_len_mean     | 50          |
# |    ep_rew_mean     | -49.8       |
# |    success_rate    | 0.020833334 |
# | time/              |             |
# |    episodes        | 48          |
# |    fps             | 332         |
# |    time_elapsed    | 7           |
# |    total_timesteps | 2400        |
# ------------------------------------
# -----------------------------------
# | rollout/           |            |
# |    ep_len_mean     | 50         |
# |    ep_rew_mean     | -49.8      |
# |    success_rate    | 0.01923077 |
# | time/              |            |
# |    episodes        | 52         |
# |    fps             | 344        |
# |    time_elapsed    | 7          |
# |    total_timesteps | 2600       |
# -----------------------------------
# ------------------------------------
# | rollout/           |             |
# |    ep_len_mean     | 50          |
# |    ep_rew_mean     | -49.7       |
# |    success_rate    | 0.017857144 |
# | time/              |             |
# |    episodes        | 56          |
# |    fps             | 355         |
# |    time_elapsed    | 7           |
# |    total_timesteps | 2800        |
# ------------------------------------
# ------------------------------------
# | rollout/           |             |
# |    ep_len_mean     | 50          |
# |    ep_rew_mean     | -49.7       |
# |    success_rate    | 0.016666668 |
# | time/              |             |
# |    episodes        | 60          |
# |    fps             | 366         |
# |    time_elapsed    | 8           |
# |    total_timesteps | 3000        |
# ------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49.7    |
# |    success_rate    | 0.015625 |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 376      |
# |    time_elapsed    | 8        |
# |    total_timesteps | 3200     |
# ---------------------------------
# ------------------------------------
# | rollout/           |             |
# |    ep_len_mean     | 50          |
# |    ep_rew_mean     | -49.7       |
# |    success_rate    | 0.014705882 |
# | time/              |             |
# |    episodes        | 68          |
# |    fps             | 385         |
# |    time_elapsed    | 8           |
# |    total_timesteps | 3400        |
# ------------------------------------
# ------------------------------------
# | rollout/           |             |
# |    ep_len_mean     | 50          |
# |    ep_rew_mean     | -49.6       |
# |    success_rate    | 0.013888889 |
# | time/              |             |
# |    episodes        | 72          |
# |    fps             | 393         |
# |    time_elapsed    | 9           |
# |    total_timesteps | 3600        |
# ------------------------------------
# ------------------------------------
# | rollout/           |             |
# |    ep_len_mean     | 50          |
# |    ep_rew_mean     | -49.7       |
# |    success_rate    | 0.013157895 |
# | time/              |             |
# |    episodes        | 76          |
# |    fps             | 400         |
# |    time_elapsed    | 9           |
# |    total_timesteps | 3800        |
# ------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49.4    |
# |    success_rate    | 0.0125   |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 401      |
# |    time_elapsed    | 9        |
# |    total_timesteps | 4000     |
# ---------------------------------
# Saving video to /home/ws/upecj/master/models/src/videos/fetch-reach/SAC_frame_stack_3dConv_p8pqnpfl/rl-video-step-4000-to-step-4200.mp4
# ------------------------------------
# | rollout/           |             |
# |    ep_len_mean     | 50          |
# |    ep_rew_mean     | -49.4       |
# |    success_rate    | 0.011904762 |
# | time/              |             |
# |    episodes        | 84          |
# |    fps             | 358         |
# |    time_elapsed    | 11          |
# |    total_timesteps | 4200        |
# ------------------------------------
# ------------------------------------
# | rollout/           |             |
# |    ep_len_mean     | 50          |
# |    ep_rew_mean     | -49.1       |
# |    success_rate    | 0.011363637 |
# | time/              |             |
# |    episodes        | 88          |
# |    fps             | 365         |
# |    time_elapsed    | 12          |
# |    total_timesteps | 4400        |
# ------------------------------------
# ------------------------------------
# | rollout/           |             |
# |    ep_len_mean     | 50          |
# |    ep_rew_mean     | -49.2       |
# |    success_rate    | 0.010869565 |
# | time/              |             |
# |    episodes        | 92          |
# |    fps             | 372         |
# |    time_elapsed    | 12          |
# |    total_timesteps | 4600        |
# ------------------------------------
# ------------------------------------
# | rollout/           |             |
# |    ep_len_mean     | 50          |
# |    ep_rew_mean     | -49.2       |
# |    success_rate    | 0.010416667 |
# | time/              |             |
# |    episodes        | 96          |
# |    fps             | 378         |
# |    time_elapsed    | 12          |
# |    total_timesteps | 4800        |
# ------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49.2    |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 384      |
# |    time_elapsed    | 12       |
# |    total_timesteps | 5000     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49.3    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 390      |
# |    time_elapsed    | 13       |
# |    total_timesteps | 5200     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49.2    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 395      |
# |    time_elapsed    | 13       |
# |    total_timesteps | 5400     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49.2    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 401      |
# |    time_elapsed    | 13       |
# |    total_timesteps | 5600     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49.2    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 406      |
# |    time_elapsed    | 14       |
# |    total_timesteps | 5800     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49.2    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 405      |
# |    time_elapsed    | 14       |
# |    total_timesteps | 6000     |
# ---------------------------------
# Saving video to /home/ws/upecj/master/models/src/videos/fetch-reach/SAC_frame_stack_3dConv_p8pqnpfl/rl-video-step-6000-to-step-6200.mp4
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49.2    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 375      |
# |    time_elapsed    | 16       |
# |    total_timesteps | 6200     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49.1    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 380      |
# |    time_elapsed    | 16       |
# |    total_timesteps | 6400     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49      |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 384      |
# |    time_elapsed    | 17       |
# |    total_timesteps | 6600     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49      |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 388      |
# |    time_elapsed    | 17       |
# |    total_timesteps | 6800     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48.8    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 392      |
# |    time_elapsed    | 17       |
# |    total_timesteps | 7000     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48.8    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 395      |
# |    time_elapsed    | 18       |
# |    total_timesteps | 7200     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48.8    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 399      |
# |    time_elapsed    | 18       |
# |    total_timesteps | 7400     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48.8    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 402      |
# |    time_elapsed    | 18       |
# |    total_timesteps | 7600     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48.9    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 405      |
# |    time_elapsed    | 19       |
# |    total_timesteps | 7800     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48.9    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 404      |
# |    time_elapsed    | 19       |
# |    total_timesteps | 8000     |
# ---------------------------------
# Saving video to /home/ws/upecj/master/models/src/videos/fetch-reach/SAC_frame_stack_3dConv_p8pqnpfl/rl-video-step-8000-to-step-8200.mp4
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48.9    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 374      |
# |    time_elapsed    | 21       |
# |    total_timesteps | 8200     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48.8    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 376      |
# |    time_elapsed    | 22       |
# |    total_timesteps | 8400     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48.8    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 379      |
# |    time_elapsed    | 22       |
# |    total_timesteps | 8600     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48.8    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 382      |
# |    time_elapsed    | 22       |
# |    total_timesteps | 8800     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48.9    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 385      |
# |    time_elapsed    | 23       |
# |    total_timesteps | 9000     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48.9    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 388      |
# |    time_elapsed    | 23       |
# |    total_timesteps | 9200     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49.1    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 391      |
# |    time_elapsed    | 24       |
# |    total_timesteps | 9400     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48.9    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 393      |
# |    time_elapsed    | 24       |
# |    total_timesteps | 9600     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48.9    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 396      |
# |    time_elapsed    | 24       |
# |    total_timesteps | 9800     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48.9    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 395      |
# |    time_elapsed    | 25       |
# |    total_timesteps | 10000    |
# ---------------------------------
# Saving video to /home/ws/upecj/master/models/src/videos/fetch-reach/SAC_frame_stack_3dConv_p8pqnpfl/rl-video-step-10000-to-step-10200.mp4
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48.9    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 40       |
# |    time_elapsed    | 253      |
# |    total_timesteps | 10200    |
# | train/             |          |
# |    actor_loss      | -4.2     |
# |    critic_loss     | 0.049    |
# |    ent_coef        | 0.826    |
# |    ent_coef_loss   | -1.28    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 199      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48.9    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 21       |
# |    time_elapsed    | 482      |
# |    total_timesteps | 10400    |
# | train/             |          |
# |    actor_loss      | -3.71    |
# |    critic_loss     | 0.077    |
# |    ent_coef        | 0.676    |
# |    ent_coef_loss   | -2.63    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 399      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48.9    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 14       |
# |    time_elapsed    | 711      |
# |    total_timesteps | 10600    |
# | train/             |          |
# |    actor_loss      | -3.23    |
# |    critic_loss     | 0.157    |
# |    ent_coef        | 0.553    |
# |    ent_coef_loss   | -4       |
# |    learning_rate   | 0.001    |
# |    n_updates       | 599      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48.8    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 11       |
# |    time_elapsed    | 941      |
# |    total_timesteps | 10800    |
# | train/             |          |
# |    actor_loss      | -3.12    |
# |    critic_loss     | 0.0168   |
# |    ent_coef        | 0.453    |
# |    ent_coef_loss   | -5.32    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 799      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48.8    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 9        |
# |    time_elapsed    | 1170     |
# |    total_timesteps | 11000    |
# | train/             |          |
# |    actor_loss      | -2.62    |
# |    critic_loss     | 0.0271   |
# |    ent_coef        | 0.371    |
# |    ent_coef_loss   | -6.68    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 999      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48.8    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    episodes        | 224      |
# |    fps             | 8        |
# |    time_elapsed    | 1399     |
# |    total_timesteps | 11200    |
# | train/             |          |
# |    actor_loss      | -2.11    |
# |    critic_loss     | 0.0117   |
# |    ent_coef        | 0.304    |
# |    ent_coef_loss   | -8.01    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1199     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48.8    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    episodes        | 228      |
# |    fps             | 7        |
# |    time_elapsed    | 1628     |
# |    total_timesteps | 11400    |
# | train/             |          |
# |    actor_loss      | -1.5     |
# |    critic_loss     | 0.0117   |
# |    ent_coef        | 0.249    |
# |    ent_coef_loss   | -9.41    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1399     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48.9    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 6        |
# |    time_elapsed    | 1857     |
# |    total_timesteps | 11600    |
# | train/             |          |
# |    actor_loss      | -0.855   |
# |    critic_loss     | 0.0301   |
# |    ent_coef        | 0.203    |
# |    ent_coef_loss   | -10.7    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1599     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48.8    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    episodes        | 236      |
# |    fps             | 5        |
# |    time_elapsed    | 2086     |
# |    total_timesteps | 11800    |
# | train/             |          |
# |    actor_loss      | -0.177   |
# |    critic_loss     | 0.0318   |
# |    ent_coef        | 0.167    |
# |    ent_coef_loss   | -12.1    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1799     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49      |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 5        |
# |    time_elapsed    | 2316     |
# |    total_timesteps | 12000    |
# | train/             |          |
# |    actor_loss      | 0.574    |
# |    critic_loss     | 0.0166   |
# |    ent_coef        | 0.136    |
# |    ent_coef_loss   | -13.4    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1999     |
# ---------------------------------
# Saving video to /home/ws/upecj/master/models/src/videos/fetch-reach/SAC_frame_stack_3dConv_p8pqnpfl/rl-video-step-12000-to-step-12200.mp4
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49      |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 244      |
# |    fps             | 4        |
# |    time_elapsed    | 2546     |
# |    total_timesteps | 12200    |
# | train/             |          |
# |    actor_loss      | 1.26     |
# |    critic_loss     | 0.032    |
# |    ent_coef        | 0.112    |
# |    ent_coef_loss   | -14.7    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2199     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49      |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 248      |
# |    fps             | 4        |
# |    time_elapsed    | 2775     |
# |    total_timesteps | 12400    |
# | train/             |          |
# |    actor_loss      | 1.86     |
# |    critic_loss     | 0.0112   |
# |    ent_coef        | 0.0914   |
# |    ent_coef_loss   | -16.1    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2399     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49      |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 252      |
# |    fps             | 4        |
# |    time_elapsed    | 3004     |
# |    total_timesteps | 12600    |
# | train/             |          |
# |    actor_loss      | 2.53     |
# |    critic_loss     | 0.0203   |
# |    ent_coef        | 0.0749   |
# |    ent_coef_loss   | -17.4    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2599     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49      |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 256      |
# |    fps             | 3        |
# |    time_elapsed    | 3233     |
# |    total_timesteps | 12800    |
# | train/             |          |
# |    actor_loss      | 3.22     |
# |    critic_loss     | 0.0131   |
# |    ent_coef        | 0.0613   |
# |    ent_coef_loss   | -18.7    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2799     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49      |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 3        |
# |    time_elapsed    | 3462     |
# |    total_timesteps | 13000    |
# | train/             |          |
# |    actor_loss      | 3.82     |
# |    critic_loss     | 0.0209   |
# |    ent_coef        | 0.0502   |
# |    ent_coef_loss   | -20.1    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2999     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49      |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 264      |
# |    fps             | 3        |
# |    time_elapsed    | 3691     |
# |    total_timesteps | 13200    |
# | train/             |          |
# |    actor_loss      | 4.46     |
# |    critic_loss     | 0.0222   |
# |    ent_coef        | 0.0411   |
# |    ent_coef_loss   | -21.4    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3199     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49      |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 268      |
# |    fps             | 3        |
# |    time_elapsed    | 3921     |
# |    total_timesteps | 13400    |
# | train/             |          |
# |    actor_loss      | 5.07     |
# |    critic_loss     | 0.0135   |
# |    ent_coef        | 0.0337   |
# |    ent_coef_loss   | -22.8    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3399     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49.1    |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 272      |
# |    fps             | 3        |
# |    time_elapsed    | 4150     |
# |    total_timesteps | 13600    |
# | train/             |          |
# |    actor_loss      | 5.72     |
# |    critic_loss     | 0.0175   |
# |    ent_coef        | 0.0276   |
# |    ent_coef_loss   | -24      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3599     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49.1    |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 276      |
# |    fps             | 3        |
# |    time_elapsed    | 4379     |
# |    total_timesteps | 13800    |
# | train/             |          |
# |    actor_loss      | 6.32     |
# |    critic_loss     | 0.0178   |
# |    ent_coef        | 0.0226   |
# |    ent_coef_loss   | -25.4    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3799     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49.3    |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 3        |
# |    time_elapsed    | 4608     |
# |    total_timesteps | 14000    |
# | train/             |          |
# |    actor_loss      | 6.91     |
# |    critic_loss     | 0.0138   |
# |    ent_coef        | 0.0185   |
# |    ent_coef_loss   | -26.6    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3999     |
# ---------------------------------
# Saving video to /home/ws/upecj/master/models/src/videos/fetch-reach/SAC_frame_stack_3dConv_p8pqnpfl/rl-video-step-14000-to-step-14200.mp4
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49.3    |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 284      |
# |    fps             | 2        |
# |    time_elapsed    | 4839     |
# |    total_timesteps | 14200    |
# | train/             |          |
# |    actor_loss      | 7.44     |
# |    critic_loss     | 0.021    |
# |    ent_coef        | 0.0152   |
# |    ent_coef_loss   | -27.7    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4199     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49.4    |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 288      |
# |    fps             | 2        |
# |    time_elapsed    | 5068     |
# |    total_timesteps | 14400    |
# | train/             |          |
# |    actor_loss      | 7.85     |
# |    critic_loss     | 0.0748   |
# |    ent_coef        | 0.0124   |
# |    ent_coef_loss   | -27.7    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4399     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49.5    |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 292      |
# |    fps             | 2        |
# |    time_elapsed    | 5296     |
# |    total_timesteps | 14600    |
# | train/             |          |
# |    actor_loss      | 6.56     |
# |    critic_loss     | 0.0157   |
# |    ent_coef        | 0.0104   |
# |    ent_coef_loss   | -28.7    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4599     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49.5    |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 296      |
# |    fps             | 2        |
# |    time_elapsed    | 5525     |
# |    total_timesteps | 14800    |
# | train/             |          |
# |    actor_loss      | 7.11     |
# |    critic_loss     | 0.0118   |
# |    ent_coef        | 0.00856  |
# |    ent_coef_loss   | -30.6    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4799     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49.5    |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 2        |
# |    time_elapsed    | 5754     |
# |    total_timesteps | 15000    |
# | train/             |          |
# |    actor_loss      | 7.68     |
# |    critic_loss     | 0.000531 |
# |    ent_coef        | 0.00703  |
# |    ent_coef_loss   | -31.8    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4999     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49.5    |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 304      |
# |    fps             | 2        |
# |    time_elapsed    | 5983     |
# |    total_timesteps | 15200    |
# | train/             |          |
# |    actor_loss      | 8.23     |
# |    critic_loss     | 0.0195   |
# |    ent_coef        | 0.00576  |
# |    ent_coef_loss   | -33.4    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5199     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49.5    |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 308      |
# |    fps             | 2        |
# |    time_elapsed    | 6212     |
# |    total_timesteps | 15400    |
# | train/             |          |
# |    actor_loss      | 8.79     |
# |    critic_loss     | 0.0085   |
# |    ent_coef        | 0.00474  |
# |    ent_coef_loss   | -34.6    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5399     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49.5    |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 312      |
# |    fps             | 2        |
# |    time_elapsed    | 6440     |
# |    total_timesteps | 15600    |
# | train/             |          |
# |    actor_loss      | 9.3      |
# |    critic_loss     | 0.0166   |
# |    ent_coef        | 0.0039   |
# |    ent_coef_loss   | -32.7    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5599     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49.6    |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 316      |
# |    fps             | 2        |
# |    time_elapsed    | 6669     |
# |    total_timesteps | 15800    |
# | train/             |          |
# |    actor_loss      | 9.8      |
# |    critic_loss     | 0.0115   |
# |    ent_coef        | 0.00322  |
# |    ent_coef_loss   | -34.9    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5799     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49.7    |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 320      |
# |    fps             | 2        |
# |    time_elapsed    | 6898     |
# |    total_timesteps | 16000    |
# | train/             |          |
# |    actor_loss      | 10.3     |
# |    critic_loss     | 0.0162   |
# |    ent_coef        | 0.00269  |
# |    ent_coef_loss   | -24.7    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5999     |
# ---------------------------------
# Saving video to /home/ws/upecj/master/models/src/videos/fetch-reach/SAC_frame_stack_3dConv_p8pqnpfl/rl-video-step-16000-to-step-16200.mp4
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49.7    |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 324      |
# |    fps             | 2        |
# |    time_elapsed    | 7128     |
# |    total_timesteps | 16200    |
# | train/             |          |
# |    actor_loss      | 10.7     |
# |    critic_loss     | 0.0157   |
# |    ent_coef        | 0.00242  |
# |    ent_coef_loss   | -25.3    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6199     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49.8    |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 328      |
# |    fps             | 2        |
# |    time_elapsed    | 7357     |
# |    total_timesteps | 16400    |
# | train/             |          |
# |    actor_loss      | 11.2     |
# |    critic_loss     | 0.0231   |
# |    ent_coef        | 0.00219  |
# |    ent_coef_loss   | -17      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6399     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49.8    |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 332      |
# |    fps             | 2        |
# |    time_elapsed    | 7586     |
# |    total_timesteps | 16600    |
# | train/             |          |
# |    actor_loss      | 11.6     |
# |    critic_loss     | 0.0116   |
# |    ent_coef        | 0.00181  |
# |    ent_coef_loss   | -40.1    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6599     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49.9    |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 336      |
# |    fps             | 2        |
# |    time_elapsed    | 7815     |
# |    total_timesteps | 16800    |
# | train/             |          |
# |    actor_loss      | 11.9     |
# |    critic_loss     | 0.0203   |
# |    ent_coef        | 0.00143  |
# |    ent_coef_loss   | -37.8    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6799     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49.9    |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 340      |
# |    fps             | 2        |
# |    time_elapsed    | 8044     |
# |    total_timesteps | 17000    |
# | train/             |          |
# |    actor_loss      | 12.3     |
# |    critic_loss     | 0.0166   |
# |    ent_coef        | 0.00139  |
# |    ent_coef_loss   | 5.06     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6999     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49.9    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    episodes        | 344      |
# |    fps             | 2        |
# |    time_elapsed    | 8273     |
# |    total_timesteps | 17200    |
# | train/             |          |
# |    actor_loss      | 12.6     |
# |    critic_loss     | 0.0234   |
# |    ent_coef        | 0.00146  |
# |    ent_coef_loss   | 22.4     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7199     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49.9    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    episodes        | 348      |
# |    fps             | 2        |
# |    time_elapsed    | 8502     |
# |    total_timesteps | 17400    |
# | train/             |          |
# |    actor_loss      | 13       |
# |    critic_loss     | 0.0384   |
# |    ent_coef        | 0.00144  |
# |    ent_coef_loss   | -23      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7399     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49.9    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    episodes        | 352      |
# |    fps             | 2        |
# |    time_elapsed    | 8730     |
# |    total_timesteps | 17600    |
# | train/             |          |
# |    actor_loss      | -0.786   |
# |    critic_loss     | 113      |
# |    ent_coef        | 0.00148  |
# |    ent_coef_loss   | 22.6     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7599     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49.9    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    episodes        | 356      |
# |    fps             | 1        |
# |    time_elapsed    | 8959     |
# |    total_timesteps | 17800    |
# | train/             |          |
# |    actor_loss      | 8.62     |
# |    critic_loss     | 0.0178   |
# |    ent_coef        | 0.00166  |
# |    ent_coef_loss   | 16.3     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7799     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49.9    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    episodes        | 360      |
# |    fps             | 1        |
# |    time_elapsed    | 9188     |
# |    total_timesteps | 18000    |
# | train/             |          |
# |    actor_loss      | 26.1     |
# |    critic_loss     | 0.113    |
# |    ent_coef        | 0.00252  |
# |    ent_coef_loss   | 224      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7999     |
# ---------------------------------
# Saving video to /home/ws/upecj/master/models/src/videos/fetch-reach/SAC_frame_stack_3dConv_p8pqnpfl/rl-video-step-18000-to-step-18200.mp4
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49.9    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    episodes        | 364      |
# |    fps             | 1        |
# |    time_elapsed    | 9419     |
# |    total_timesteps | 18200    |
# | train/             |          |
# |    actor_loss      | 57       |
# |    critic_loss     | 0.143    |
# |    ent_coef        | 0.00374  |
# |    ent_coef_loss   | 210      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8199     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49.9    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    episodes        | 368      |
# |    fps             | 1        |
# |    time_elapsed    | 9648     |
# |    total_timesteps | 18400    |
# | train/             |          |
# |    actor_loss      | 61       |
# |    critic_loss     | 0.104    |
# |    ent_coef        | 0.00514  |
# |    ent_coef_loss   | 198      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8399     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49.9    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    episodes        | 372      |
# |    fps             | 1        |
# |    time_elapsed    | 9877     |
# |    total_timesteps | 18600    |
# | train/             |          |
# |    actor_loss      | 60.3     |
# |    critic_loss     | 0.081    |
# |    ent_coef        | 0.00682  |
# |    ent_coef_loss   | 187      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8599     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49.9    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    episodes        | 376      |
# |    fps             | 1        |
# |    time_elapsed    | 10106    |
# |    total_timesteps | 18800    |
# | train/             |          |
# |    actor_loss      | 58.8     |
# |    critic_loss     | 0.0866   |
# |    ent_coef        | 0.00883  |
# |    ent_coef_loss   | 177      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8799     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49.9    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    episodes        | 380      |
# |    fps             | 1        |
# |    time_elapsed    | 10335    |
# |    total_timesteps | 19000    |
# | train/             |          |
# ...
# |    episodes        | 452      |
# |    fps             | 1        |
# |    time_elapsed    | 14463    |
# |    total_timesteps | 22600    |
# | train/             |          |
# |    actor_loss      | 146      |
# |    critic_loss     | 1.41     |
# |    ent_coef        | 0.488    |
# |    ent_coef_loss   | 27.1     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 12599    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49.9    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    episodes        | 456      |
# |    fps             | 1        |
# |    time_elapsed    | 14692    |
# |    total_timesteps | 22800    |
# | train/             |          |
# |    actor_loss      | 172      |
# |    critic_loss     | 0.997    |
# |    ent_coef        | 0.596    |
# |    ent_coef_loss   | 19.4     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 12799    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49.9    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    episodes        | 460      |
# |    fps             | 1        |
# |    time_elapsed    | 14921    |
# |    total_timesteps | 23000    |
# | train/             |          |
# |    actor_loss      | 201      |
# |    critic_loss     | 2.09     |
# |    ent_coef        | 0.728    |
# |    ent_coef_loss   | 11.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 12999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49.9    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    episodes        | 464      |
# |    fps             | 1        |
# |    time_elapsed    | 15150    |
# |    total_timesteps | 23200    |
# | train/             |          |
# |    actor_loss      | 238      |
# |    critic_loss     | 3.27     |
# |    ent_coef        | 0.89     |
# |    ent_coef_loss   | 4.37     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 13199    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49.9    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    episodes        | 468      |
# |    fps             | 1        |
# |    time_elapsed    | 15379    |
# |    total_timesteps | 23400    |
# | train/             |          |
# |    actor_loss      | 284      |
# |    critic_loss     | 4.03     |
# |    ent_coef        | 1.09     |
# |    ent_coef_loss   | -3.16    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 13399    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49.9    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    episodes        | 472      |
# |    fps             | 1        |
# |    time_elapsed    | 15608    |
# |    total_timesteps | 23600    |
# | train/             |          |
# |    actor_loss      | 338      |
# |    critic_loss     | 6.49     |
# |    ent_coef        | 1.33     |
# |    ent_coef_loss   | -10.7    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 13599    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49.9    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    episodes        | 476      |
# |    fps             | 1        |
# |    time_elapsed    | 15837    |
# |    total_timesteps | 23800    |
# | train/             |          |
# |    actor_loss      | 407      |
# |    critic_loss     | 5.18     |
# |    ent_coef        | 1.62     |
# |    ent_coef_loss   | -18.2    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 13799    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49.9    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    episodes        | 480      |
# |    fps             | 1        |
# |    time_elapsed    | 16067    |
# |    total_timesteps | 24000    |
# | train/             |          |
# |    actor_loss      | 488      |
# |    critic_loss     | 12.9     |
# |    ent_coef        | 1.98     |
# |    ent_coef_loss   | -25.7    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 13999    |
# ---------------------------------
# Saving video to /home/ws/upecj/master/models/src/videos/fetch-reach/SAC_frame_stack_3dConv_p8pqnpfl/rl-video-step-24000-to-step-24200.mp4
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49.9    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    episodes        | 484      |
# |    fps             | 1        |
# |    time_elapsed    | 16297    |
# |    total_timesteps | 24200    |
# | train/             |          |
# |    actor_loss      | 589      |
# |    critic_loss     | 11.6     |
# |    ent_coef        | 2.42     |
# |    ent_coef_loss   | -33.2    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 14199    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49.9    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    episodes        | 488      |
# |    fps             | 1        |
# |    time_elapsed    | 16526    |
# |    total_timesteps | 24400    |
# | train/             |          |
# |    actor_loss      | 713      |
# |    critic_loss     | 17.1     |
# |    ent_coef        | 2.96     |
# |    ent_coef_loss   | -40.7    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 14399    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49.9    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    episodes        | 492      |
# |    fps             | 1        |
# |    time_elapsed    | 16755    |
# |    total_timesteps | 24600    |
# | train/             |          |
# |    actor_loss      | 860      |
# |    critic_loss     | 34.2     |
# |    ent_coef        | 3.62     |
# |    ent_coef_loss   | -48.4    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 14599    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49.9    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    episodes        | 496      |
# |    fps             | 1        |
# |    time_elapsed    | 16985    |
# |    total_timesteps | 24800    |
# | train/             |          |
# |    actor_loss      | 1.04e+03 |
# |    critic_loss     | 38.1     |
# |    ent_coef        | 4.42     |
# |    ent_coef_loss   | -55.8    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 14799    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49.9    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    episodes        | 500      |
# |    fps             | 1        |
# |    time_elapsed    | 17214    |
# |    total_timesteps | 25000    |
# | train/             |          |
# |    actor_loss      | 1.26e+03 |
# |    critic_loss     | 69.6     |
# |    ent_coef        | 5.39     |
# |    ent_coef_loss   | -63.2    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 14999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49.9    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    episodes        | 504      |
# |    fps             | 1        |
# |    time_elapsed    | 17443    |
# |    total_timesteps | 25200    |
# | train/             |          |
# |    actor_loss      | 1.53e+03 |
# |    critic_loss     | 113      |
# |    ent_coef        | 6.59     |
# |    ent_coef_loss   | -70.8    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 15199    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49.9    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    episodes        | 508      |
# |    fps             | 1        |
# |    time_elapsed    | 17672    |
# |    total_timesteps | 25400    |
# | train/             |          |
# |    actor_loss      | 1.86e+03 |
# |    critic_loss     | 136      |
# |    ent_coef        | 8.05     |
# |    ent_coef_loss   | -78.5    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 15399    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49.9    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    episodes        | 512      |
# |    fps             | 1        |
# |    time_elapsed    | 17901    |
# |    total_timesteps | 25600    |
# | train/             |          |
# |    actor_loss      | 2.25e+03 |
# |    critic_loss     | 243      |
# |    ent_coef        | 9.83     |
# |    ent_coef_loss   | -86.3    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 15599    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49.9    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    episodes        | 516      |
# |    fps             | 1        |
# |    time_elapsed    | 18130    |
# |    total_timesteps | 25800    |
# | train/             |          |
# |    actor_loss      | 2.74e+03 |
# |    critic_loss     | 298      |
# |    ent_coef        | 12       |
# |    ent_coef_loss   | -93.4    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 15799    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49.9    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    episodes        | 520      |
# |    fps             | 1        |
# |    time_elapsed    | 18360    |
# |    total_timesteps | 26000    |
# | train/             |          |
# |    actor_loss      | 3.33e+03 |
# |    critic_loss     | 417      |
# |    ent_coef        | 14.7     |
# |    ent_coef_loss   | -101     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 15999    |
# ---------------------------------
# Saving video to /home/ws/upecj/master/models/src/videos/fetch-reach/SAC_frame_stack_3dConv_p8pqnpfl/rl-video-step-26000-to-step-26200.mp4
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49.9    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    episodes        | 524      |
# |    fps             | 1        |
# |    time_elapsed    | 18590    |
# |    total_timesteps | 26200    |
# | train/             |          |
# |    actor_loss      | 4.08e+03 |
# |    critic_loss     | 647      |
# |    ent_coef        | 17.9     |
# |    ent_coef_loss   | -108     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 16199    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49.9    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    episodes        | 528      |
# |    fps             | 1        |
# |    time_elapsed    | 18819    |
# |    total_timesteps | 26400    |
# | train/             |          |
# |    actor_loss      | 4.93e+03 |
# |    critic_loss     | 1.41e+03 |
# |    ent_coef        | 21.9     |
# |    ent_coef_loss   | -116     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 16399    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49.9    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    episodes        | 532      |
# |    fps             | 1        |
# |    time_elapsed    | 19048    |
# |    total_timesteps | 26600    |
# | train/             |          |
# |    actor_loss      | 6.05e+03 |
# |    critic_loss     | 1.85e+03 |
# |    ent_coef        | 26.7     |
# |    ent_coef_loss   | -123     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 16599    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49.9    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    episodes        | 536      |
# |    fps             | 1        |
# |    time_elapsed    | 19278    |
# |    total_timesteps | 26800    |
# | train/             |          |
# |    actor_loss      | 7.35e+03 |
# |    critic_loss     | 2.84e+03 |
# |    ent_coef        | 32.6     |
# |    ent_coef_loss   | -131     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 16799    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49.9    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    episodes        | 540      |
# |    fps             | 1        |
# |    time_elapsed    | 19507    |
# |    total_timesteps | 27000    |
# | train/             |          |
# |    actor_loss      | 8.99e+03 |
# |    critic_loss     | 2.82e+03 |
# |    ent_coef        | 39.9     |
# |    ent_coef_loss   | -138     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 16999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49.9    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    episodes        | 544      |
# |    fps             | 1        |
# |    time_elapsed    | 19736    |
# |    total_timesteps | 27200    |
# | train/             |          |
# |    actor_loss      | 1.1e+04  |
# |    critic_loss     | 4.78e+03 |
# |    ent_coef        | 48.7     |
# |    ent_coef_loss   | -146     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 17199    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49.9    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    episodes        | 548      |
# |    fps             | 1        |
# |    time_elapsed    | 19965    |
# |    total_timesteps | 27400    |
# | train/             |          |
# |    actor_loss      | 1.33e+04 |
# |    critic_loss     | 8e+03    |
# |    ent_coef        | 59.5     |
# |    ent_coef_loss   | -153     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 17399    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49.9    |
# |    success_rate    | 0.0      |
# | time/              |          |
# |    episodes        | 552      |
# |    fps             | 1        |
# |    time_elapsed    | 20194    |
# |    total_timesteps | 27600    |
# | train/             |          |
# |    actor_loss      | 1.64e+04 |
# |    critic_loss     | 9.51e+03 |
# |    ent_coef        | 72.6     |
# |    ent_coef_loss   | -161     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 17599    |
# ---------------------------------

# %%
run.finish()
# Out:
# <br/>Waiting for W&B process to finish, PID 2157606... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value=' 13.88MB of 13.88MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col">
# <h3>Run history:</h3><br/><table class="wandb"><tr><td>global_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>rollout/ep_len_mean</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>rollout/ep_rew_mean</td><td>▃▂▆▆█▇▇▅▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>rollout/success_rate</td><td>█▃▂▁▁▁▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>time/fps</td><td>▆▇███▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/actor_loss</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂█</td></tr><tr><td>train/critic_loss</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁█          </td></tr><tr><td>train/ent_coef</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂█</td></tr><tr><td>train/ent_coef_loss</td><td>██▇▇████▇▇▇▇▇▆▆▆▆▆▅▅▅▅▅▄▄▄▄▄▃▃▃▃▂▂▂▂▂▁▁▁</td></tr><tr><td>train/learning_rate</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col">
# <h3>Run summary:</h3><br/><table class="wandb"><tr><td>global_step</td><td>79600</td></tr><tr><td>rollout/ep_len_mean</td><td>50.0</td></tr><tr><td>rollout/ep_rew_mean</td><td>-49.93</td></tr><tr><td>rollout/success_rate</td><td>0.0</td></tr><tr><td>time/fps</td><td>0.0</td></tr><tr><td>train/actor_loss</td><td>1.1390430967029916e+26</td></tr><tr><td>train/critic_loss</td><td>inf</td></tr><tr><td>train/ent_coef</td><td>2.74221745763911e+24</td></tr><tr><td>train/ent_coef_loss</td><td>-2112.25439</td></tr><tr><td>train/learning_rate</td><td>0.001</td></tr></table>
# </div></div>
# Synced 5 W&B file(s), 40 media file(s), 0 artifact file(s) and 2 other file(s)
# <br/>Synced <strong style="color:#cdcd00">SAC_frame_stack_3dConv</strong>: <a href="https://wandb.ai/f-krone/fetch-reach/runs/p8pqnpfl" target="_blank">https://wandb.ai/f-krone/fetch-reach/runs/p8pqnpfl</a><br/>
# Find logs at: <code>./wandb/run-20220224_125840-p8pqnpfl/logs</code><br/>

# %%
video_folder = 'logs/videos/'
video_length = 500
env_id=config["env_name"]
name = "SAC_multiInput_custom"

test_env = DummyVecEnv([make_env])

# Record the video starting at the first step
test_env = VecVideoRecorder(test_env, video_folder,
                       record_video_trigger=lambda x: x == 0, video_length=video_length,
                       name_prefix=f"{name}-{env_id}")
obs = test_env.reset()
test_model = SAC.load(f"{name}_fetch", env=test_env)

for _ in range(video_length + 1):
  action, _states = test_model.predict(obs, deterministic=True)
  obs, _, _, _ = test_env.step(action)
# Save the video
test_env.close()
# Out:
# Saving video to /home/ws/upecj/master/models/logs/videos/SAC_multiInput_custom-CustomFetchPickAndPlaceDense-v0-step-0-to-step-500.mp4
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# /tmp/ipykernel_2552816/1764734502.py in <module>
#      15 for _ in range(video_length + 1):
#      16   action, _states = test_model.predict(obs, deterministic=True)
# ---> 17   obs, _, _, _ = test_env.step(action)
#      18 # Save the video
#      19 test_env.close()
#
# ~/master/models/venv/lib/python3.8/site-packages/stable_baselines3/common/vec_env/base_vec_env.py in step(self, actions)
#     160         """
#     161         self.step_async(actions)
# --> 162         return self.step_wait()
#     163
#     164     def get_images(self) -> Sequence[np.ndarray]:
#
# ~/master/models/venv/lib/python3.8/site-packages/stable_baselines3/common/vec_env/vec_video_recorder.py in step_wait(self)
#      94             if self.recorded_frames > self.video_length:
#      95                 print(f"Saving video to {self.video_recorder.path}")
# ---> 96                 self.close_video_recorder()
#      97         elif self._video_enabled():
#      98             self.start_video_recorder()
#
# ~/master/models/venv/lib/python3.8/site-packages/stable_baselines3/common/vec_env/vec_video_recorder.py in close_video_recorder(self)
#     102     def close_video_recorder(self) -> None:
#     103         if self.recording:
# --> 104             self.video_recorder.close()
#     105         self.recording = False
#     106         self.recorded_frames = 1
#
# ~/master/models/venv/lib/python3.8/site-packages/gym/wrappers/monitoring/video_recorder.py in close(self)
#     151         if self.encoder:
#     152             logger.debug("Closing video encoder: path=%s", self.path)
# --> 153             self.encoder.close()
#     154             self.encoder = None
#     155         else:
#
# ~/master/models/venv/lib/python3.8/site-packages/wandb/integration/gym/__init__.py in close(self)
#      18         else:
#      19             key = "videos"
# ---> 20         wandb.log({key: wandb.Video(self.output_path)})
#      21
#      22     vcr.ImageEncoder.close = close
#
# ~/master/models/venv/lib/python3.8/site-packages/wandb/sdk/lib/preinit.py in preinit_wrapper(*args, **kwargs)
#      36 def PreInitCallable(name, destination=None):  # noqa: N802
#      37     def preinit_wrapper(*args, **kwargs):
# ---> 38         raise wandb.Error("You must call wandb.init() before {}()".format(name))
#      39
#      40     preinit_wrapper.__name__ = str(name)
#
# Error: You must call wandb.init() before wandb.log()
